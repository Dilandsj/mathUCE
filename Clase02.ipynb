# %% [markdown]
# <a href="https://colab.research.google.com/github/Dilandsj/mathUCE/blob/main/Clase02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ALGORITMOS DE PROGRAMACIÓN Y SISTEMAS NÚMERICOS

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # PROPOSICIONES

# %% [markdown]
# **NEGACION**
#
# COMO SE DECIA ANTERIORMENTE LA NEGACION CAMBIA EL VALOR DE VERDAD DE UNA PROPOSICION
#
# P "TODO ELEMENTO DE A ES GRANDE"
#
# ¬P "TODO ELEMENTO DE A ES PEQUEÑO"

# %% [markdown]
# **NEGACIONDE CUANTIFICADORES**
#
#  LA NEGACION DE UN CUANTIFICADOR ES EL CUANTIFICADOR OPUESTO SIN EMBARGO NO CAMBIA EL SENTIDO DE PERTENENCIA PERO SI CAMBIA EL SIMBOLO DE MAYOR O MENOR O IGUAL QUE

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # DIAGRAMA DE FLUJO

# %% [markdown]
# ALGORITMO
#
# TIENE UN INICIO Y UN FIN
#
# POSEE UN DIAGRAMA DE FLUJO
#
# SIGUE UN CONJUNTO DE PASOS POR EJEMPLO QUEREMOS CALCULAR UNA SUMA ENTONCES PRIMERO ASIGNAMOS QUE LA MAQUINA LEEA EL PRIMER VALOR A TRAVES DE LA DIGITACION EN EL TECLADO LUEGO ASIGNAMOS QUE LEA EL SEGUNDO VALOR LUEGO ASIGNAMOS QUE HAGA UN PROCESO EN EL QUE CALCULE LA SUMA Y POR ULTIMO ASIGNAMOS QUE ESCRIBA OSEA NOS MUESTRE EN LA PANTALLA EL RESULTADO.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # EPS

# %% [markdown]
# SE REFIERE A EL PROCESO QUE SIGUE UN ALGORITMO QUE ES ENTRADA PROCESO SALIDA SE REFIERE EN LA ENTRADA A LO QUE SE DIGITA EN EL TECLADO, EN EL PROCESO A AL PROCESO QUE HACE LA MAQUINA AL PROCESAMIENTO DE DATOS PARA REALIZAR ACCIONES COMO SUMAR, RESTAR,MULTIPLICAR, ETC; Y EN LA SALIDA MUESTRA EL RESULTADO DEL PROCESO QUE REALIZO LA MAQUINA.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # BUSQUEDA BINARIA Y LINEAL

# %% [markdown]
# EN LA BUSQUEDA LINEAL SE VA DE NUMERO EN NUMERO HASTA ENCONTAR EN NUMERO DESEADO Y LA CANTIDAD DE PASOS DEPENDE DE LA EXTENSION DEL CONJUNTO DE DATOS

# %% [markdown]
# NOS ES DE MUCHA UTILIDAD LA BUSQUEDA BINARIA YA QUE PERMITE ENCONTRAR UN NUMERO EN UN CONJUNTO DE DATOS DIVIDIENDO AL CONJUNTO EN LA MITAD REDUCIENDO LOS PASOS PARTA ENCONTRAR UN NUMERO
#
# SE PUEDE UTILIZAR EL LOGARIRMO EN BASE 2 DE UN NUMERO PARA SABER CUANTO PASOS NOS VAMOS A TARDAR PARA ENCONTRAR ESE NUMERO

# %% [markdown]
# EN PROGRAMACION LA CANTIDAD DE BITS DEPENDE DEL NUMERO DE PREGUNTAS QUE SE DEBE REALIZAR PARA LLEGAR A UNA RESPUESTA ESTO SE LO PUEDE A TRAVES DEL LOGARITMO EN BASE 2

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # SISTEMAS NUMERICOS

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # SIMETRIZACION

# %% [markdown]
# ES BUSCAR UN NUMERO SIMETRICO A PARTIR DE CONSTANTES QUE SE ENCUENTRAN EN UN SISTEMA NUMERICO
#
# POR EJEMPLO
#
# X+2=4
#
# X=4-2
#
# X=2
#
# SI REEMPLAZAMOS EL VALOR DE X CON EL VALOR SIMETRICO ENONTRADO NOS CUMPLIRA LA IGUALDAD
#
# PERO ES MUY IMPORTANTE TENER EN CUENTA LAS LEYES DE SIGNOS

# %% [markdown]
# TAMBIEN TENEMOS UN NUEVO CONJUNTO DE NUMEROS QUE ES EL DE LOS NUMEROS COMPLEJOS A PARTIR DE LOS NUMERO IMAGINARIOS QUE SURGEN A TRAVES DE LA RAIZ DE UN NUMERO NEGATIVO
#
# ESTE CONJUNTO CONTIENE A TODOS LOS NUMEROS N
# N⊂Z⊂Q⊂R⊂C

# %% [markdown]
# ![image.png](data:image/png;base64,...)
